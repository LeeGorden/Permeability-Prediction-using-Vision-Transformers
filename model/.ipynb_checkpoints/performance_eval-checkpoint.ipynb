# %%
"""
Author: LiGorden
Email: likehao1006@gmail.com

Check the performance of model
"""
import os
import gc
import random
import torch
from torch import nn
from torch.utils.data import Dataset
from torchvision import transforms, datasets

import numpy as np
from sklearn.metrics import roc_auc_score
import shap
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ### Result of using z direction mpa data, split train/test by sample

# %%
# ----------------------For directly calculate accurate for ViT 16----------------------
root_result_ViT_16 = os.path.abspath(os.path.join(os.getcwd(), "..", "result", "model_trained", "ViT", "split_by_sample"))
result_ViT_16_pred = np.load(os.path.join(root_result_ViT_16, "pred.npy"))
result_ViT_16_true = np.load(os.path.join(root_result_ViT_16, "true.npy"))
result_ViT_16_time = np.load(os.path.join(root_result_ViT_16, "time_best_epoch.npy"))
result_ViT_16_train_loss = np.load(os.path.join(root_result_ViT_16, "train_loss.npy"))
result_ViT_16_test_loss = np.load(os.path.join(root_result_ViT_16, "test_loss.npy"))
result_ViT_16_pred_all = np.load(os.path.join(root_result_ViT_16, "pred_all_data.npy"))
result_ViT_16_true_all = np.load(os.path.join(root_result_ViT_16, "true_all_data.npy"))

result_ViT_16_pred_train = np.load(os.path.join(root_result_ViT_16, "pred_train_data.npy"))
result_ViT_16_true_train = np.load(os.path.join(root_result_ViT_16, "true_train_data.npy"))
result_ViT_16_pred_test = np.load(os.path.join(root_result_ViT_16, "pred_test_data.npy"))
result_ViT_16_true_test = np.load(os.path.join(root_result_ViT_16, "true_test_data.npy"))

# %%
# plot the training/test loss
plt.figure()
plt.title("Best MSE loss of log10(permeability): " + str(np.min(result_ViT_16_test_loss)))
plt.xlim((0, 100))
plt.ylim((0, 0.1))
plt.plot(result_ViT_16_train_loss, label="train")
plt.plot(result_ViT_16_test_loss, label="test")
plt.legend()

# %%
# check the boxplot of relative error
relative_error = abs((10 ** result_ViT_16_pred - 10 ** result_ViT_16_true) / (10 ** result_ViT_16_true) * 100)
plt.title("Avg relative_error:" + str(round(np.mean(relative_error), 3)) + "%")
plt.boxplot(relative_error)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26655c1d940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26655c1de80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26655c1d6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x26655c2d3a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26655c2d640>],
#  'means': []}

# %%
# plot the true value and pred value
x = np.linspace(7.1, 8.8, 50)
y = x

plt.figure()
plt.title("log(permeability)")
plt.xlabel("true")
plt.ylabel("pred")
plt.xlim(7.1, 8.8)
plt.ylim(7.1, 8.8)
plt.plot(x, y, color='green', linewidth=1.0, linestyle='--')
plt.scatter(result_ViT_16_true, result_ViT_16_pred)

# %%
# plot the true value and pred value
x = np.linspace(7.1, 8.8, 50)
y = x

plt.figure()
plt.title("log(permeability)")
plt.xlabel("true")
plt.ylabel("pred")
plt.xlim(7.1, 8.8)
plt.ylim(7.1, 8.8)
plt.plot(x, y, color='green', linewidth=1.0, linestyle='--')
train_plt = plt.scatter(result_ViT_16_true_train, result_ViT_16_pred_train, color='blue', alpha = 0.3, s=8)
test_plt = plt.scatter(result_ViT_16_true_test, result_ViT_16_pred_test, color='orange', alpha = 0.3, s=8)
plt.legend((train_plt, test_plt), ("train", "test"), loc="best")

# %% [markdown]
# ### Result of using z direction mpa data and elec data, split train/test by sample + concat MPa & elec channel wise

# %%
# ----------------------For directly calculate accurate for ViT 16----------------------
root_result_ViT_16 = os.path.abspath(os.path.join(os.getcwd(), "..", "result", "model_trained", "ViT_concat_by_channel"))
result_ViT_16_pred = np.load(os.path.join(root_result_ViT_16, "pred.npy"))
result_ViT_16_true = np.load(os.path.join(root_result_ViT_16, "true.npy"))
result_ViT_16_time = np.load(os.path.join(root_result_ViT_16, "time_best_epoch.npy"))
result_ViT_16_train_loss = np.load(os.path.join(root_result_ViT_16, "train_loss.npy"))
result_ViT_16_test_loss = np.load(os.path.join(root_result_ViT_16, "test_loss.npy"))
result_ViT_16_pred_all = np.load(os.path.join(root_result_ViT_16, "pred_all_data.npy"))
result_ViT_16_true_all = np.load(os.path.join(root_result_ViT_16, "true_all_data.npy"))

result_ViT_16_pred_train = np.load(os.path.join(root_result_ViT_16, "pred_train_data.npy"))
result_ViT_16_true_train = np.load(os.path.join(root_result_ViT_16, "true_train_data.npy"))
result_ViT_16_pred_test = np.load(os.path.join(root_result_ViT_16, "pred_test_data.npy"))
result_ViT_16_true_test = np.load(os.path.join(root_result_ViT_16, "true_test_data.npy"))

# %%
# plot the training/test loss
plt.figure()
plt.title("Best MSE loss of log10(permeability): " + str(np.min(result_ViT_16_test_loss)))
plt.xlim((0, 100))
plt.ylim((0, 0.1))
plt.plot(result_ViT_16_train_loss, label="train")
plt.plot(result_ViT_16_test_loss, label="test")
plt.legend()

# %%
# check the boxplot of relative error
relative_error = abs((10 ** result_ViT_16_pred - 10 ** result_ViT_16_true) / (10 ** result_ViT_16_true) * 100)
plt.title("Avg relative_error:" + str(round(np.mean(relative_error), 3)) + "%")
plt.boxplot(relative_error)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26655321820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26655321d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26655321580>],
#  'medians': [<matplotlib.lines.Line2D at 0x266555602e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26655560580>],
#  'means': []}

# %%
# plot the true value and pred value
x = np.linspace(7.1, 8.8, 50)
y = x

plt.figure()
plt.title("log(permeability)")
plt.xlabel("true")
plt.ylabel("pred")
plt.xlim(7.1, 8.8)
plt.ylim(7.1, 8.8)
plt.plot(x, y, color='green', linewidth=1.0, linestyle='--')
plt.scatter(result_ViT_16_true, result_ViT_16_pred)

# %%
# plot the true value and pred value
x = np.linspace(7.1, 8.8, 50)
y = x

plt.figure()
plt.title("log(permeability)")
plt.xlabel("true")
plt.ylabel("pred")
plt.xlim(7.1, 8.8)
plt.ylim(7.1, 8.8)
plt.plot(x, y, color='green', linewidth=1.0, linestyle='--')
train_plt = plt.scatter(result_ViT_16_true_train, result_ViT_16_pred_train, color='blue', alpha = 0.3, s=8)
test_plt = plt.scatter(result_ViT_16_true_test, result_ViT_16_pred_test, color='orange', alpha = 0.3, s=8)
plt.legend((train_plt, test_plt), ("train", "test"), loc="best")

# %% [markdown]
# ### Result of using z direction mpa data and elec data, using 2 ViT separately

# %%
# ----------------------For directly calculate accurate for ViT 16----------------------
root_result_ViT_16 = os.path.abspath(os.path.join(os.getcwd(), "..", "result", "model_trained", "ViT_double_branch"))
result_ViT_16_pred = np.load(os.path.join(root_result_ViT_16, "36-65", "pred.npy"))
result_ViT_16_true = np.load(os.path.join(root_result_ViT_16, "36-65", "true.npy"))
result_ViT_16_train_loss_35 = np.load(os.path.join(root_result_ViT_16, "1-35", "train_loss_temp.npy"))
result_ViT_16_test_loss_35 = np.load(os.path.join(root_result_ViT_16, "1-35", "test_loss_temp.npy"))
result_ViT_16_train_loss_65 = np.load(os.path.join(root_result_ViT_16, "36-65", "train_loss_temp.npy"))
result_ViT_16_test_loss_65 = np.load(os.path.join(root_result_ViT_16, "36-65", "test_loss_temp.npy"))
result_ViT_16_pred_all = np.load(os.path.join(root_result_ViT_16, "36-65", "pred_all_data.npy"))
result_ViT_16_true_all = np.load(os.path.join(root_result_ViT_16, "36-65", "true_all_data.npy"))

result_ViT_16_pred_train = np.load(os.path.join(root_result_ViT_16, "36-65", "pred_train_data.npy"))
result_ViT_16_true_train = np.load(os.path.join(root_result_ViT_16, "36-65", "true_train_data.npy"))
result_ViT_16_pred_test = np.load(os.path.join(root_result_ViT_16, "36-65", "pred_test_data.npy"))
result_ViT_16_true_test = np.load(os.path.join(root_result_ViT_16, "36-65", "true_test_data.npy"))

# %%
result_ViT_16_train_loss = np.concatenate([result_ViT_16_train_loss_35, result_ViT_16_train_loss_65[-15:]])
result_ViT_16_test_loss = np.concatenate([result_ViT_16_test_loss_65, result_ViT_16_test_loss_65[-15:]])

# %%
# plot the training/test loss
plt.figure()
plt.title("Best MSE loss of log10(permeability): " + str(np.min(result_ViT_16_test_loss)))
plt.xlim((0, len(result_ViT_16_train_loss)))
plt.ylim((0, 0.1))
plt.plot(result_ViT_16_train_loss, label="train")
plt.plot(result_ViT_16_test_loss, label="test")
plt.legend()

# %%
# check the boxplot of relative error
relative_error = abs((10 ** result_ViT_16_pred - 10 ** result_ViT_16_true) / (10 ** result_ViT_16_true) * 100)
plt.title("Avg relative_error:" + str(round(np.mean(relative_error), 3)) + "%")
plt.boxplot(relative_error)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x266570e1f70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x266570f04f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x266570e1cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x266570f0a30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x266570f0cd0>],
#  'means': []}

# %%
# plot the true value and pred value
x = np.linspace(7.1, 8.8, 50)
y = x

plt.figure()
plt.title("log(permeability)")
plt.xlabel("true")
plt.ylabel("pred")
plt.xlim(7.1, 8.8)
plt.ylim(7.1, 8.8)
plt.plot(x, y, color='green', linewidth=1.0, linestyle='--')
plt.scatter(result_ViT_16_true, result_ViT_16_pred)

# %%
# plot the true value and pred value
x = np.linspace(7.1, 8.8, 50)
y = x

plt.figure()
plt.title("log(permeability)")
plt.xlabel("true")
plt.ylabel("pred")
plt.xlim(7.1, 8.8)
plt.ylim(7.1, 8.8)
plt.plot(x, y, color='green', linewidth=1.0, linestyle='--')
train_plt = plt.scatter(result_ViT_16_true_train, result_ViT_16_pred_train, color='blue', alpha = 0.3, s=8)
test_plt = plt.scatter(result_ViT_16_true_test, result_ViT_16_pred_test, color='orange', alpha = 0.3, s=8)
plt.legend((train_plt, test_plt), ("train", "test"), loc="best")
